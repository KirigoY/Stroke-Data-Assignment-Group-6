# %%
# Importing the libraries we will need

# Importing the pandas library

import pandas as pd

# Importing the numpy library

import numpy as np

# Importing the seaborn library
import seaborn as sns

# Importing the matplotlib library

import matplotlib.pyplot as plt

# %%
# Loading the dataset
f = (r"C:\Users\Kish\Documents\DATA SCIENCE\DSFPT06\stroke_data.csv")
df = pd.read_csv(f)

# %%
# Inspecting the dataset.  Preview the dataset
df.head()
# Out:
#       id  gender   age  hypertension  heart_disease ever_married  \
# 0   9046    Male  67.0             0              1          Yes
# 1  51676  Female  61.0             0              0          Yes
# 2  31112    Male  80.0             0              1          Yes
# 3  60182  Female  49.0             0              0          Yes
# 4   1665  Female  79.0             1              0          Yes
#
#        work_type Residence_type  avg_glucose_level   bmi   smoking_status  \
# 0        Private          Urban             228.69  36.6  formerly smoked
# 1  Self-employed          Rural             202.21   NaN     never smoked
# 2        Private          Rural             105.92  32.5     never smoked
# 3        Private          Urban             171.23  34.4           smokes
# 4  Self-employed          Rural             174.12  24.0     never smoked
#
#    stroke
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1

# %%
# Inspecting the dataset.
df.tail()
# Out:
#          id  gender   age  hypertension  heart_disease ever_married  \
# 5105  18234  Female  80.0             1              0          Yes
# 5106  44873  Female  81.0             0              0          Yes
# 5107  19723  Female  35.0             0              0          Yes
# 5108  37544    Male  51.0             0              0          Yes
# 5109  44679  Female  44.0             0              0          Yes
#
#           work_type Residence_type  avg_glucose_level   bmi   smoking_status  \
# 5105        Private          Urban              83.75   NaN     never smoked
# 5106  Self-employed          Urban             125.20  40.0     never smoked
# 5107  Self-employed          Rural              82.99  30.6     never smoked
# 5108        Private          Rural             166.29  25.6  formerly smoked
# 5109       Govt_job          Urban              85.28  26.2          Unknown
#
#       stroke
# 5105       0
# 5106       0
# 5107       0
# 5108       0
# 5109       0

# %%
# Inspecting the dataset.
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5110 entries, 0 to 5109
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 5110 non-null   int64
#  1   gender             5110 non-null   object
#  2   age                5110 non-null   float64
#  3   hypertension       5110 non-null   int64
#  4   heart_disease      5110 non-null   int64
#  5   ever_married       5110 non-null   object
#  6   work_type          5110 non-null   object
#  7   Residence_type     5110 non-null   object
#  8   avg_glucose_level  5110 non-null   float64
#  9   bmi                4909 non-null   float64
#  10  smoking_status     5110 non-null   object
#  11  stroke             5110 non-null   int64
# dtypes: float64(3), int64(4), object(5)
# memory usage: 479.2+ KB

# %%
# Inspecting the dataset.
df.describe()
# Out:
#                  id          age  hypertension  heart_disease  \
# count   5110.000000  5110.000000   5110.000000    5110.000000
# mean   36517.829354    43.226614      0.097456       0.054012
# std    21161.721625    22.612647      0.296607       0.226063
# min       67.000000     0.080000      0.000000       0.000000
# 25%    17741.250000    25.000000      0.000000       0.000000
# 50%    36932.000000    45.000000      0.000000       0.000000
# 75%    54682.000000    61.000000      0.000000       0.000000
# max    72940.000000    82.000000      1.000000       1.000000
#
#        avg_glucose_level          bmi       stroke
# count        5110.000000  4909.000000  5110.000000
# mean          106.147677    28.893237     0.048728
# std            45.283560     7.854067     0.215320
# min            55.120000    10.300000     0.000000
# 25%            77.245000    23.500000     0.000000
# 50%            91.885000    28.100000     0.000000
# ...

# %%
# Inspecting the dataset.
df.shape
# Out:
# (5110, 12)

# %%
# Checking for null values in the data set.
df.isna()
# Out:
#          id  gender    age  hypertension  heart_disease  ever_married  \
# 0     False   False  False         False          False         False
# 1     False   False  False         False          False         False
# 2     False   False  False         False          False         False
# 3     False   False  False         False          False         False
# 4     False   False  False         False          False         False
# ...     ...     ...    ...           ...            ...           ...
# 5105  False   False  False         False          False         False
# 5106  False   False  False         False          False         False
# 5107  False   False  False         False          False         False
# 5108  False   False  False         False          False         False
# 5109  False   False  False         False          False         False
#
#       work_type  Residence_type  avg_glucose_level    bmi  smoking_status  \
# ...

# %%
# getting the number of null values
df.isna().sum()
# Out:
# id                     0
# gender                 0
# age                    0
# hypertension           0
# heart_disease          0
# ever_married           0
# work_type              0
# Residence_type         0
# avg_glucose_level      0
# bmi                  201
# smoking_status         0
# stroke                 0
# dtype: int64

# %%
# Getting the mean of the null alues in the data set
df.isna().mean()*100
# Out:
# id                   0.000000
# gender               0.000000
# age                  0.000000
# hypertension         0.000000
# heart_disease        0.000000
# ever_married         0.000000
# work_type            0.000000
# Residence_type       0.000000
# avg_glucose_level    0.000000
# bmi                  3.933464
# smoking_status       0.000000
# stroke               0.000000
# dtype: float64

# %% [markdown]
# The BMI column has 4% null values

# %%
# Lets get the rows that have missing data
df[df.isnull().any(axis=1)]
# Out:
#          id  gender   age  hypertension  heart_disease ever_married  \
# 1     51676  Female  61.0             0              0          Yes
# 8     27419  Female  59.0             0              0          Yes
# 13     8213    Male  78.0             0              1          Yes
# 19    25226    Male  57.0             0              1           No
# 27    61843    Male  58.0             0              0          Yes
# ...     ...     ...   ...           ...            ...          ...
# 5039  42007    Male  41.0             0              0           No
# 5048  28788    Male  40.0             0              0          Yes
# 5093  32235  Female  45.0             1              0          Yes
# 5099   7293    Male  40.0             0              0          Yes
# 5105  18234  Female  80.0             1              0          Yes
#
#           work_type Residence_type  avg_glucose_level  bmi   smoking_status  \
# ...

# %%
# Checking for unique values
df.nunique()
# Out:
# id                   5110
# gender                  3
# age                   104
# hypertension            2
# heart_disease           2
# ever_married            2
# work_type               5
# Residence_type          2
# avg_glucose_level    3979
# bmi                   418
# smoking_status          4
# stroke                  2
# dtype: int64

# %%
# Replacing the null values with the mean of the BMI
df['bmi'].fillna(df['bmi'].mean(), inplace=True)

# %%
# Checking that the null values have been replaced
df.isna()
# Out:
#          id  gender    age  hypertension  heart_disease  ever_married  \
# 0     False   False  False         False          False         False
# 1     False   False  False         False          False         False
# 2     False   False  False         False          False         False
# 3     False   False  False         False          False         False
# 4     False   False  False         False          False         False
# ...     ...     ...    ...           ...            ...           ...
# 5105  False   False  False         False          False         False
# 5106  False   False  False         False          False         False
# 5107  False   False  False         False          False         False
# 5108  False   False  False         False          False         False
# 5109  False   False  False         False          False         False
#
#       work_type  Residence_type  avg_glucose_level    bmi  smoking_status  \
# ...

# %%
df.describe()
# Out:
#                  id          age  hypertension  heart_disease  \
# count   5110.000000  5110.000000   5110.000000    5110.000000
# mean   36517.829354    43.226614      0.097456       0.054012
# std    21161.721625    22.612647      0.296607       0.226063
# min       67.000000     0.080000      0.000000       0.000000
# 25%    17741.250000    25.000000      0.000000       0.000000
# 50%    36932.000000    45.000000      0.000000       0.000000
# 75%    54682.000000    61.000000      0.000000       0.000000
# max    72940.000000    82.000000      1.000000       1.000000
#
#        avg_glucose_level          bmi       stroke
# count        5110.000000  5110.000000  5110.000000
# mean          106.147677    28.893237     0.048728
# std            45.283560     7.698018     0.215320
# min            55.120000    10.300000     0.000000
# 25%            77.245000    23.800000     0.000000
# 50%            91.885000    28.400000     0.000000
# ...

# %%
df.head()
# Out:
#       id  gender   age  hypertension  heart_disease ever_married  \
# 0   9046    Male  67.0             0              1          Yes
# 1  51676  Female  61.0             0              0          Yes
# 2  31112    Male  80.0             0              1          Yes
# 3  60182  Female  49.0             0              0          Yes
# 4   1665  Female  79.0             1              0          Yes
#
#        work_type Residence_type  avg_glucose_level        bmi  \
# 0        Private          Urban             228.69  36.600000
# 1  Self-employed          Rural             202.21  28.893237
# 2        Private          Rural             105.92  32.500000
# 3        Private          Urban             171.23  34.400000
# 4  Self-employed          Rural             174.12  24.000000
#
#     smoking_status  stroke
# 0  formerly smoked       1
# 1     never smoked       1
# 2     never smoked       1
# 3           smokes       1
# 4     never smoked       1

# %%
# Lets check for duplicates
df.duplicated().value_counts()
# Out:
# False    5110
# Name: count, dtype: int64

# %% [markdown]
# We do not have duplicates

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5110 entries, 0 to 5109
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 5110 non-null   int64
#  1   gender             5110 non-null   object
#  2   age                5110 non-null   float64
#  3   hypertension       5110 non-null   int64
#  4   heart_disease      5110 non-null   int64
#  5   ever_married       5110 non-null   object
#  6   work_type          5110 non-null   object
#  7   Residence_type     5110 non-null   object
#  8   avg_glucose_level  5110 non-null   float64
#  9   bmi                5110 non-null   float64
#  10  smoking_status     5110 non-null   object
#  11  stroke             5110 non-null   int64
# dtypes: float64(3), int64(4), object(5)
# memory usage: 479.2+ KB

# %%
# Lets check for outliers. Lets plot our boxplot
# using seaborn
sns.boxplot(data=df)
plt.title('Stroke Data Boxplot')
# Out:
# Text(0.5, 1.0, 'Stroke Data Boxplot')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5110 entries, 0 to 5109
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 5110 non-null   int64
#  1   gender             5110 non-null   object
#  2   age                5110 non-null   float64
#  3   hypertension       5110 non-null   int64
#  4   heart_disease      5110 non-null   int64
#  5   ever_married       5110 non-null   object
#  6   work_type          5110 non-null   object
#  7   Residence_type     5110 non-null   object
#  8   avg_glucose_level  5110 non-null   float64
#  9   bmi                5110 non-null   float64
#  10  smoking_status     5110 non-null   object
#  11  stroke             5110 non-null   int64
# dtypes: float64(3), int64(4), object(5)
# memory usage: 479.2+ KB

# %%
# Changing the data type of id to a string
column_name = 'id'
df[column_name] = df[column_name].astype(str)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5110 entries, 0 to 5109
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 5110 non-null   object
#  1   gender             5110 non-null   object
#  2   age                5110 non-null   float64
#  3   hypertension       5110 non-null   int64
#  4   heart_disease      5110 non-null   int64
#  5   ever_married       5110 non-null   object
#  6   work_type          5110 non-null   object
#  7   Residence_type     5110 non-null   object
#  8   avg_glucose_level  5110 non-null   float64
#  9   bmi                5110 non-null   float64
#  10  smoking_status     5110 non-null   object
#  11  stroke             5110 non-null   int64
# dtypes: float64(3), int64(3), object(6)
# memory usage: 479.2+ KB

# %%
# Lets check for outliers. Lets plot our boxplot
# using seaborn
sns.boxplot(data=df)
plt.title('Stroke Data Boxplot')
# Out:
# Text(0.5, 1.0, 'Stroke Data Boxplot')

# %% [markdown]
# The dataset has outliers in the glucose levels and bmi

# %%
df.describe()
# Out:
#                age  hypertension  heart_disease  avg_glucose_level  \
# count  5110.000000   5110.000000    5110.000000        5110.000000
# mean     43.226614      0.097456       0.054012         106.147677
# std      22.612647      0.296607       0.226063          45.283560
# min       0.080000      0.000000       0.000000          55.120000
# 25%      25.000000      0.000000       0.000000          77.245000
# 50%      45.000000      0.000000       0.000000          91.885000
# 75%      61.000000      0.000000       0.000000         114.090000
# max      82.000000      1.000000       1.000000         271.740000
#
#                bmi       stroke
# count  5110.000000  5110.000000
# mean     28.893237     0.048728
# std       7.698018     0.215320
# min      10.300000     0.000000
# 25%      23.800000     0.000000
# 50%      28.400000     0.000000
# 75%      32.800000     0.000000
# max      97.600000     1.000000

# %%
# Checking for outliers Using matplotlib
df.plot(kind='box')
# Out:
# <Axes: >

# %% [markdown]
# There are no oultiers in the dataset

# %% [markdown]
# Exploratory Data Analysis

# %%
# We shall check the statistical summaries
df.describe()
# Out:
#                age  hypertension  heart_disease  avg_glucose_level  \
# count  5110.000000   5110.000000    5110.000000        5110.000000
# mean     43.226614      0.097456       0.054012         106.147677
# std      22.612647      0.296607       0.226063          45.283560
# min       0.080000      0.000000       0.000000          55.120000
# 25%      25.000000      0.000000       0.000000          77.245000
# 50%      45.000000      0.000000       0.000000          91.885000
# 75%      61.000000      0.000000       0.000000         114.090000
# max      82.000000      1.000000       1.000000         271.740000
#
#                bmi       stroke
# count  5110.000000  5110.000000
# mean     28.893237     0.048728
# std       7.698018     0.215320
# min      10.300000     0.000000
# 25%      23.800000     0.000000
# 50%      28.400000     0.000000
# 75%      32.800000     0.000000
# max      97.600000     1.000000

# %% [markdown]
# The oldest patient is 82 years while the youngest is under a year old. The average age of the patients is 43.2 years.
# The highest recorded glucose level is 271.74, the lowest recorded level is 55.1. The average glucose level is 106.1.
# The highest recorded bmi is 97.6, the lowest recorded bmi is 10.3. The average glucose level is 28.89.

# %%
# To calculate measures of central tendencies, we use their functions
df.mean(numeric_only=True)
# Out:
# age                   43.226614
# hypertension           0.097456
# heart_disease          0.054012
# avg_glucose_level    106.147677
# bmi                   28.893237
# stroke                 0.048728
# dtype: float64

# %%
# Median
df.median(numeric_only=True)
# Out:
# age                  45.000
# hypertension          0.000
# heart_disease         0.000
# avg_glucose_level    91.885
# bmi                  28.400
# stroke                0.000
# dtype: float64

# %%
# mode
df.mode(numeric_only=True)
# Out:
#     age  hypertension  heart_disease  avg_glucose_level        bmi  stroke
# 0  78.0             0              0              93.88  28.893237       0

# %%
# standard deviation
df.std(numeric_only=True)
# Out:
# age                  22.612647
# hypertension          0.296607
# heart_disease         0.226063
# avg_glucose_level    45.283560
# bmi                   7.698018
# stroke                0.215320
# dtype: float64

# %%
# variance 
df.var(numeric_only=True)
# Out:
# age                   511.331792
# hypertension            0.087976
# heart_disease           0.051104
# avg_glucose_level    2050.600820
# bmi                    59.259478
# stroke                  0.046363
# dtype: float64

# %%
# Checking for skewness
df.skew(numeric_only=True)
# Out:
# age                 -0.137059
# hypertension         2.715392
# heart_disease        3.947244
# avg_glucose_level    1.572284
# bmi                  1.076716
# stroke               4.193284
# dtype: float64

# %%
# Checking for kurtosis
df.kurt(numeric_only=True)
# Out:
# age                  -0.991010
# hypertension          5.375456
# heart_disease        13.586052
# avg_glucose_level     1.680479
# bmi                   3.623061
# stroke               15.589736
# dtype: float64

# %%
# Data visualization

df.hist()
plt.figure(figsize=(4, 7))

# %%
# Lets now calculate how many of each unique value are in the columns
gender = df['gender'].value_counts()
gender
# Out:
# gender
# Female    2994
# Male      2115
# Other        1
# Name: count, dtype: int64

# %%
# Lets now calculate how many of each unique value are in the columns
age = df['age'].value_counts()
age
# Out:
# age
# 78.00    102
# 57.00     95
# 52.00     90
# 54.00     87
# 51.00     86
#         ...
# 1.40       3
# 0.48       3
# 0.16       3
# 0.40       2
# 0.08       2
# Name: count, Length: 104, dtype: int64

# %%
# Lets now calculate how many of each unique value are in the columns
glucose = df['avg_glucose_level'].value_counts()
glucose
# Out:
# avg_glucose_level
# 93.88     6
# 91.68     5
# 91.85     5
# 83.16     5
# 73.00     5
#          ..
# 111.93    1
# 94.40     1
# 95.57     1
# 66.29     1
# 85.28     1
# Name: count, Length: 3979, dtype: int64

# %%
# Lets now calculate how many of each unique value are in the columns
bmi = df['bmi'].value_counts()
bmi
# Out:
# bmi
# 28.893237    201
# 28.700000     41
# 28.400000     38
# 27.600000     37
# 26.700000     37
#             ...
# 11.500000      1
# 40.600000      1
# 53.900000      1
# 97.600000      1
# 14.900000      1
# Name: count, Length: 419, dtype: int64

# %%
# Lets plot this
gender.plot(kind='bar')
# Out:
# <Axes: xlabel='gender'>

# %%
# We seek to check the most common age
df['age'].value_counts().head(10)
# Out:
# age
# 78.0    102
# 57.0     95
# 52.0     90
# 54.0     87
# 51.0     86
# 45.0     85
# 79.0     85
# 53.0     85
# 55.0     83
# 50.0     83
# Name: count, dtype: int64

# %% [markdown]
# 102 of the patients are 78 Years old

# %%
# Data Visualization of age distribution

df['age'].hist(color = 'orange',grid=False,figsize=(10,5),bins=df['age'].nunique(),density=True)
plt.title('age distribution')
plt.ylabel('count')
plt.xlabel('Age')
# Out:
# Text(0.5, 0, 'Age')

# %%
# Data Visualization of bmi distribution


df['bmi'].hist(color = 'green',grid=False,figsize=(10,5),bins=df['bmi'].nunique(),density=True)
plt.title('bmi distribution')
plt.ylabel('count')
plt.xlabel('BMI')
# Out:
# Text(0.5, 0, 'BMI')

# %%
# Data Visualization of Average glucose levels distribution


df['avg_glucose_level'].hist(color = 'blue',grid=False,figsize=(10,5),bins=df['avg_glucose_level'].nunique(),density=True)
plt.title('Average Glucose Level distribution')
plt.ylabel('count')
plt.xlabel('Average Glucose Level')
# Out:
# Text(0.5, 0, 'Average Glucose Level')

# %%
# Data Visualization of stroke distribution

df['stroke'].hist(color = 'yellow',grid=False,figsize=(10,5),bins=df['stroke'].nunique(),density=True)
plt.title('Stroke distribution')
plt.ylabel('count')
plt.xlabel('Stroke')
# Out:
# Text(0.5, 0, 'Stroke')

# %%
# Data Visualization of stroke distribution

df['stroke'].value_counts().plot(kind='pie',autopct = '%1.1f%%')
plt.title('Strokes distribution ')
# Out:
# Text(0.5, 1.0, 'Strokes distribution ')

# %%
# Data Visualization of gender distribution
df['gender'].value_counts().plot(kind='pie',autopct = '%1.1f%%')
plt.title('Gender distribution ')
# Out:
# Text(0.5, 1.0, 'Gender distribution ')

# %%
# Data Visualization of worktype distribution
df['work_type'].value_counts().plot(kind='pie',autopct = '%1.1f%%')
plt.title('Worktype distribution ')
# Out:
# Text(0.5, 1.0, 'Worktype distribution ')

# %%
# Data Visualization of smoking status distribution
df['smoking_status'].value_counts().plot(kind='pie',autopct = '%1.1f%%')
plt.title('Smoking Status distribution ')
# Out:
# Text(0.5, 1.0, 'Smoking Status distribution ')

# %% [markdown]
# Exploratory Data Analysis

# %%
# Checking the correlation

df.corr(numeric_only=True)
# Out:
#                         age  hypertension  heart_disease  avg_glucose_level  \
# age                1.000000      0.276398       0.263796           0.238171
# hypertension       0.276398      1.000000       0.108306           0.174474
# heart_disease      0.263796      0.108306       1.000000           0.161857
# avg_glucose_level  0.238171      0.174474       0.161857           1.000000
# bmi                0.325942      0.160189       0.038899           0.168751
# stroke             0.245257      0.127904       0.134914           0.131945
#
#                         bmi    stroke
# age                0.325942  0.245257
# hypertension       0.160189  0.127904
# heart_disease      0.038899  0.134914
# avg_glucose_level  0.168751  0.131945
# bmi                1.000000  0.038947
# stroke             0.038947  1.000000

# %%
# checking the correlation of hypertension , heart disease and stroke

df[['hypertension','heart_disease','stroke']].corr()
# Out:
#                hypertension  heart_disease    stroke
# hypertension       1.000000       0.108306  0.127904
# heart_disease      0.108306       1.000000  0.134914
# stroke             0.127904       0.134914  1.000000

# %%
# Plotting the correlation heatmap of hypertension , heart disease and stroke

plt.figure(figsize=(8, 6))
heatmap = sns.heatmap(df[['hypertension','heart_disease','stroke']].corr(numeric_only=True),annot=True, cmap='YlGn_r')

#
heatmap.set_title('Correlation Heatmap', fontdict={'fontsize':12}, pad=12);

# %%
# Plotting the correlation heatmap of age , average glucose levels and stroke

plt.figure(figsize=(8, 6))
heatmap = sns.heatmap(df[['age','avg_glucose_level','stroke']].corr(numeric_only=True),annot=True, cmap='YlGn_r')

#
heatmap.set_title('Correlation Heatmap', fontdict={'fontsize':12}, pad=12);

# %%
# Features scaling

plt.figure(figsize=(8, 12))
heatmap = sns.heatmap(df.corr(numeric_only=True)[['bmi']].sort_values(by='bmi', ascending=False), vmin=-1, vmax=1, annot=True, cmap='BrBG')
heatmap.set_title('Features Correlating with BMI', fontdict={'fontsize':18}, pad=16);

# %%
# Features scaling

plt.figure(figsize=(8, 12))
heatmap = sns.heatmap(df.corr(numeric_only=True)[['age']].sort_values(by='age', ascending=False), vmin=-1, vmax=1, annot=True, cmap='BrBG')
heatmap.set_title('Features Correlating with Age', fontdict={'fontsize':18}, pad=16);

# %%
# Cross tabulation of heart disease and stroke
pd.crosstab(df['heart_disease'],df['stroke'])
# Out:
# stroke            0    1
# heart_disease
# 0              4632  202
# 1               229   47

# %% [markdown]
# 229 patients have heart disease but no stroke.
# 202 Patients have a stroke but no heart disease
# 47 patients have both heart disease and stroke
# 4632 patients neither have heart disease nor a stroke

# %%
# lets plot a line plot of strokes against the patient's ages
sns.lineplot(data=df,x=df['age'],y=df['stroke'])
plt.title('Age vs Stroke')
sns.lineplot(x=df['age'], y=df['stroke'], label='Age')
sns.lineplot(x=df['age'], y=df['stroke'], label='Stroke')
# Out:
# C:\Users\Kish\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\Kish\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\Kish\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# ...

# %%
# lets plot a line plot of strokes against hypertension
sns.lineplot(data=df,x=df['hypertension'],y=df['stroke'])
plt.title('Hypertension vs Stroke')
sns.lineplot(x=df['hypertension'], y=df['stroke'], label='Hypertension')
sns.lineplot(x=df['hypertension'], y=df['stroke'], label='Stroke')
# Out:
# C:\Users\Kish\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\Kish\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\Kish\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# ...

# %% [markdown]
# Stroke and age of the patients are positively correlated. The older the patient, the more likely they are to suffer from stroke.

# %%
# lets plot a line plot of strokes against the patients heart health
sns.lineplot(data=df,x=df['heart_disease'],y=df['stroke'])
plt.title('Heart Disease vs Stroke')
sns.lineplot(x=df['heart_disease'], y=df['stroke'], label='Heart Disease')
sns.lineplot(x=df['heart_disease'], y=df['stroke'], label='Stroke')
# Out:
# C:\Users\Kish\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\Kish\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\Kish\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# ...

# %% [markdown]
# Stroke and heart disease history of the patients are positively correlated. The patients with heart disease are more likely they are to suffer from stroke.

# %%
# lets plot a line plot of strokes against the patients marital history
sns.lineplot(data=df,x=df['ever_married'],y=df['stroke'])
plt.title('Marital History vs Stroke')
sns.lineplot(x=df['ever_married'], y=df['stroke'], label='Marital History')
sns.lineplot(x=df['ever_married'], y=df['stroke'], label='Stroke')
# Out:
# C:\Users\Kish\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\Kish\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\Kish\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# ...

# %% [markdown]
# Stroke and the marital history of the patients are positively correlated. The patients who have ever been married are more likely to suffer from stroke.

# %%
# lets plot a line plot of strokes against the patients gender
sns.lineplot(data=df,x=df['gender'],y=df['stroke'])
plt.title('Gender vs Stroke')
sns.lineplot(x=df['gender'], y=df['stroke'], label='Gender')
sns.lineplot(x=df['gender'], y=df['stroke'], label='Stroke')
# Out:
# C:\Users\Kish\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\Kish\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\Kish\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# ...

# %% [markdown]
# The male patients are more likely to suffer stroke compared to the female patients with others having the lowest likelihood of suffering from stroke.

# %%
# lets plot a line plot of strokes against the patients work type
sns.lineplot(data=df,x=df['work_type'],y=df['stroke'])
plt.title('Work Type vs Stroke')
sns.lineplot(x=df['work_type'], y=df['stroke'], label='Work Type')
sns.lineplot(x=df['work_type'], y=df['stroke'], label='Stroke')
# Out:
# C:\Users\Kish\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\Kish\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\Kish\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# ...

# %% [markdown]
# The self-employed patients have the highest likelihood of suffering from a stroke, followed by the patients working in the private sector and government jobs. The children and patients who have never worked before have the lowest likelihood of suffering a stroke.
# Self employment is a risk factor in causing stroke

# %%
# lets plot a line plot of strokes against the patients residence
sns.lineplot(data=df,x=df['Residence_type'],y=df['stroke'])
plt.title('Residence vs Stroke')
sns.lineplot(x=df['Residence_type'], y=df['stroke'], label='Residence')
sns.lineplot(x=df['Residence_type'], y=df['stroke'], label='Stroke')
# Out:
# C:\Users\Kish\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\Kish\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\Kish\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# ...

# %% [markdown]
# The patients living in urban areas have a higher likelihood of suffering from a stroke as comapred to the patients iliving in rural areas.
# Living in urban areas is a risk factor in causing stroke

# %%
# lets plot a line plot of strokes against the patients glucose levels
sns.lineplot(data=df,x=df['avg_glucose_level'],y=df['stroke'])
plt.title('Glucose Levels vs Stroke')
# sns.lineplot(x=df['avg_glucose_level'], y=df['stroke'], label='Glucose Level')
# sns.lineplot(x=df['avg_glucose_level'], y=df['stroke'], label='Stroke')
# Out:
# C:\Users\Kish\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\Kish\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# Text(0.5, 1.0, 'Glucose Levels vs Stroke')

# %% [markdown]
# Glucose levels in the patients do not necesarily affect the likelihood of a stroke.

# %%
# lets plot a line plot of strokes against the patients BMI levels
sns.lineplot(data=df,x=df['bmi'],y=df['stroke'])
plt.title('BMI vs Stroke')
sns.lineplot(x=df['bmi'], y=df['stroke'], label='BMI')
sns.lineplot(x=df['bmi'], y=df['stroke'], label='Stroke')
# Out:
# C:\Users\Kish\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\Kish\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\Kish\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# ...

# %% [markdown]
# Patients with abnormal (higher) BMI levels are more likely to suffer a stroke as compared to patients with normal (lower) BMI levels.
# Higher BMI levels are a risk factor in causing stroke

# %%
# lets plot a line plot of strokes against the patients smoking status
sns.lineplot(data=df,x=df['smoking_status'],y=df['stroke'])
plt.title('Smoking Status vs Stroke')
sns.lineplot(x=df['smoking_status'], y=df['stroke'], label='Smoking Status')
sns.lineplot(x=df['smoking_status'], y=df['stroke'], label='Stroke')
# Out:
# C:\Users\Kish\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\Kish\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\Kish\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# ...

# %% [markdown]
# Patients who have formerly smoked have  a higher likelihood of suffering from stroke.
# Patients who have never smoke and those that currently smoke have an equal likelihood of suffering from a stroke.
# The lowest likelihood of suffering stroke was observed from the patients whose smoking status was unknown.
# Smoking therefore is a risk factor in causing stroke.
